# %% [markdown]
# ## Importação das bibliotecas

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Carregar os dados do MNIST

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# ## Normalizar os dados

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## Converter rótulos para categóricos (one-hot encoding)

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ## Construir o modelo

# %% [markdown]
# ### Definição do modelo

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# ## Compilação do modelo

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### Treinamento do modelo

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8049 - loss: 7.0376
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9014 - loss: 0.4077
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9251 - loss: 0.3002
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9376 - loss: 0.2345
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9414 - loss: 0.2285

# %% [markdown]
# ### Avaliação do modelo

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Acurácia no conjunto de teste: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9308 - loss: 0.3143
# Acurácia no conjunto de teste: 0.9402999877929688
